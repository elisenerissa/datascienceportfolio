# %% [markdown]
# Ideas:
# - Find out what people are looking for in a certain products by analysing the reviews (may improve search engine or helpful for marketing the products/bringing the right products)
# - Find out what people are saying about these products (especially the negative comments) to find out how to improve services or even the product itself
# - sellers rating
#
# By: sentiment analysis and topic modelling

# %%
import pandas as pd 
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

plt.style.use('fivethirtyeight')
# %matplotlib inline

#pd.set_option('display.max_colwidth',None)

# %%
sellers = pd.read_csv('../data/sellers_information_selenium_all.csv')

# %%
reviews = pd.read_csv('../data/amazon_cells_v2.csv')
items = pd.read_csv('../data/amazon_items_v2.csv')

# %%
sellers.isnull().sum()
# Out:
# url          0
# sellers    214
# dtype: int64

# %%
len(sellers['sellers'].unique())
# Out:
# 163

# %%
sellers.shape
# Out:
# (720, 2)

# %%
sellers.head()
# Out:
#                                                  url              sellers
# 0  https://www.amazon.com/Dual-Band-Tri-Mode-Acti...  Flip n Smart Phones
# 1  https://www.amazon.com/Motorola-i265-I265-phon...        FOREVER ITEMS
# 2  https://www.amazon.com/MOTOROLA-C168i-CINGULAR...      DiscountGoods4U
# 3  https://www.amazon.com/Motorola-i335-Phone-Boo...         Deals on OEM
# 4  https://www.amazon.com/Motorola-V365-contract-...        Maverick Macs

# %%
sellers.loc[0,'url']
# Out:
# 'https://www.amazon.com/Dual-Band-Tri-Mode-Activated-Dialing-Backlit/dp/B0000SX2UC'

# %%
reviews.shape
# Out:
# (67986, 8)

# %%
items.shape
# Out:
# (720, 10)

# %%
new_items = pd.merge(items,sellers,on='url',how='left')

# %%
#reviews.head(2)

# %%
new_items.shape
# Out:
# (720, 11)

# %%
new_items.rename(columns={'title':'item_title'},inplace=True)
reviews.rename(columns={'title':'review_title'},inplace=True)

# %%
new_items.drop('rating',axis=1,inplace=True)
items.shape
# Out:
# (720, 10)

# %%
reviews.duplicated(subset=['name','asin','date','review_title','body']).sum()
# Out:
# 39

# %%
reviews.drop_duplicates(subset=['name','asin','date','review_title','body'],keep='first',inplace=True)
reviews.shape
# Out:
# (67947, 8)

# %%
new_reviews = pd.merge(reviews,new_items,on='asin',how='left')

# %%
new_items.head(2)
# Out:
#          asin     brand                                         item_title  \
# 0  B0000SX2UC       NaN  Dual-Band / Tri-Mode Sprint PCS Phone w/ Voice...
# 1  B0009N5L7K  Motorola                                Motorola I265 phone
#
#                                                  url  \
# 0  https://www.amazon.com/Dual-Band-Tri-Mode-Acti...
# 1  https://www.amazon.com/Motorola-i265-I265-phon...
#
#                                                image  \
# 0  https://m.media-amazon.com/images/I/2143EBQ210...
# 1  https://m.media-amazon.com/images/I/419WBAVDAR...
#
#                                            reviewUrl  totalReviews  price  \
# 0  https://www.amazon.com/product-reviews/B0000SX2UC            14   0.00
# 1  https://www.amazon.com/product-reviews/B0009N5L7K             7  49.95
#
#    originalPrice              sellers
# 0            0.0  Flip n Smart Phones
# 1            0.0        FOREVER ITEMS

# %%
print(new_reviews.shape)
#new_reviews.head(2)
# Out:
# (67947, 17)

# %%
new_reviews.isnull().sum()
# Out:
# asin                 0
# name                 2
# rating               0
# date                 0
# verified             0
# review_title        14
# body                21
# helpfulVotes     40761
# brand              200
# item_title           0
# url                  0
# image                0
# reviewUrl            0
# totalReviews         0
# price                0
# originalPrice        0
# sellers          19423
# dtype: int64

# %%
67947-19423
# Out:
# 48524

# %%
new_reviews['sellers'].value_counts()
# Out:
# Edge Cellular                4942
# Maverick Macs                2366
# Battcell                     1894
# Cell Universal               1876
# MegaElectron.                1800
#                              ...
# Fabulous Finds of the PNW       1
# KICKmobiles®                    1
# Seller1ON1                      1
# RoamtheWorld                    1
# cellulartech                    1
# Name: sellers, Length: 162, dtype: int64

# %%
len(reviews['asin'].unique())
# Out:
# 720

# %%
len(items['asin'].unique())
# Out:
# 720

# %%
reviews.loc[0,'body']
# Out:
# "I had the Samsung A600 for awhile which is absolute doo doo. You can read my review on it and detect my rage at the stupid thing. It finally died on me so I used this Nokia phone I bought in a garage sale for $1. I wonder y she sold it so cheap?... Bad: ===> I hate the menu. It takes forever to get to what you want because you have to scroll endlessly. Usually phones have numbered categories so u can simply press the # and get where you want to go. ===> It's a pain to put it on silent or vibrate. If you're in class and it rings, you have to turn it off immediately. There's no fast way to silence the damn thing. Always remember to put it on silent! I learned that the hard way. ===> It's so true about the case. It's a mission to get off and will break ur nails in the process. Also, you'll damage the case each time u try. For some reason the phone started giving me problems once I did succeed in opening it. ===> Buttons could be a bit bigger. Vibration could be stronger. Good: ===> Reception is not too shabby. I was using it in the elevator which is a remarkable feat considering my old phone would lose service by simply putting it in my pocket. ===> Compared to my old Samsung, this phone works quite well. The ring tones are loud enough to hear and the phone actually charges quickly and has great battery life. It doesn't heat up like a potatoe in the oven either during long phone convos. ===> Nice bright, large screen. ===> Cute ways to customize it. Scroll bar can be set to purple, pink, aqua, orange, etc. Overall: Okay phone. It serves its purpose but definitely pales in comparison to these new phones coming out from Sprint. Why get so so when you can get great?"

# %%
date_columns = pd.to_datetime(new_reviews['date'])

# %%
date_columns.dt.year.value_counts()
# Out:
# 2019    29688
# 2018    13732
# 2017     8181
# 2016     5508
# 2015     4439
# 2014     3314
# 2013     2144
# 2012      721
# 2011      102
# 2010       54
# 2009       36
# 2004        9
# 2008        6
# 2007        5
# 2005        4
# 2006        2
# 2003        2
# Name: date, dtype: int64

# %%
date_columns.min()
# Out:
# Timestamp('2003-11-24 00:00:00')

# %%
date_columns.max()
# Out:
# Timestamp('2019-12-25 00:00:00')

# %% [markdown]
# ## EDA

# %%
items.groupby('brand')['asin'].count().sort_values()
# Out:
# brand
# ASUS          5
# OnePlus      10
# Sony         27
# HUAWEI       32
# Google       38
# Nokia        44
# Xiaomi       46
# Apple        63
# Motorola    105
# Samsung     346
# Name: asin, dtype: int64

# %%
new_reviews.hist(column='helpfulVotes', by='brand',figsize=(8,10),range=(0,20));

# %%
plt.figure(figsize=(10,6))

reviews['helpfulVotes'].plot.hist(label='Helpful Votes',range=(0,40),bins=30)
plt.show()

# %%
items.groupby('brand')['asin'].count().sort_values().plot(kind='barh',
                                                          figsize=(7,5),
                                                         color='xkcd:rust')


plt.show()

# %%
new_reviews.columns
# Out:
# Index(['asin', 'name', 'rating', 'date', 'verified', 'review_title', 'body',
#        'helpfulVotes', 'brand', 'item_title', 'url', 'image', 'reviewUrl',
#        'totalReviews', 'price', 'originalPrice', 'sellers'],
#       dtype='object')

# %%
new_reviews.groupby('brand')['rating'].mean().sort_values().plot(kind='barh',
                                                          figsize=(7,5),
                                                          title="Average rating per brand",
                                                          color='xkcd:rust')


plt.show()

# %%
# Average rating per brand
ratings_by_brand = new_reviews.groupby("brand")['rating'].mean()
ratings_by_brand.sort_values(ascending=False)
# Out:
# brand
# Xiaomi      4.371202
# HUAWEI      4.240899
# OnePlus     4.213256
# Motorola    3.817792
# Sony        3.786921
# Samsung     3.781689
# ASUS        3.721116
# Apple       3.701263
# Google      3.585205
# Nokia       3.583996
# Name: rating, dtype: float64

# %%
ratings_by_brand = items.groupby("brand")['rating'].mean()
ratings_by_brand.sort_values(ascending=False)
# Out:
# brand
# Xiaomi      4.415217
# HUAWEI      4.021875
# ASUS        3.860000
# Sony        3.788889
# Apple       3.782540
# Google      3.771053
# Motorola    3.643810
# Samsung     3.632659
# OnePlus     3.580000
# Nokia       3.386364
# Name: rating, dtype: float64

# %% [markdown]
# ### Pre-processing of Reviews

# %%
import re
from bs4 import BeautifulSoup
from nltk.corpus import stopwords 
from nltk.stem import WordNetLemmatizer
from nltk.stem.porter import PorterStemmer
from sklearn.feature_extraction.text import CountVectorizer,TfidfVectorizer

# %%
new_reviews.columns
# Out:
# Index(['asin', 'name', 'rating', 'date', 'verified', 'review_title', 'body',
#        'helpfulVotes', 'brand', 'item_title', 'url', 'image', 'reviewUrl',
#        'totalReviews', 'price', 'originalPrice', 'sellers'],
#       dtype='object')

# %%
def all_text(row):
    """ a function to merge the title and selftext of the posts"""
    row['reviews'] = str(row['review_title']) + " " + str(row['body'])
    return row

# %%
new_reviews= new_reviews.apply(all_text, axis=1)

# %%
new_reviews['brand'].value_counts()
# Out:
# Samsung     33608
# Motorola     8869
# Nokia        5911
# Apple        5145
# Xiaomi       4410
# Google       3785
# Sony         3196
# HUAWEI       2225
# OnePlus       347
# ASUS          251
# Name: brand, dtype: int64

# %%
samsung_reviews = new_reviews[new_reviews['brand']=='Samsung']
motorola_reviews = new_reviews[new_reviews['brand']=='Motorola']
nokia_reviews = new_reviews[new_reviews['brand']=='Nokia']
apple_reviews = new_reviews[new_reviews['brand']=='Apple']
xiaomi_reviews = new_reviews[new_reviews['brand']=='Xiaomi']
google_reviews = new_reviews[new_reviews['brand']=='Google']
sony_reviews = new_reviews[new_reviews['brand']=='Sony']
huawei_reviews = new_reviews[new_reviews['brand']=='HUAWEI']
oneplus_reviews = new_reviews[new_reviews['brand']=='Oneplus']
asus_reviews = new_reviews[new_reviews['brand']=='Asus']

# %%
stop_words = stopwords.words('english')
len(stop_words)
# Out:
# 179

# %%
add_words = ['phone','one','two','three','four','five','star']

stop_words.extend(add_words)

# %%
len(stop_words)
# Out:
# 186

# %%
def clean_reviews(raw_text):
    """
    Function to convert a raw review to a string of words that have been cleaned. 
    - HTML, non-letters will be removed
    - words will be converted to lowercase
    - stopwords will be removed 
    - words will be stemmed to their root words
    
    The input is a single string, and 
    the output is a single string 
    
    """
    
    # Remove HTML.
    post_text = BeautifulSoup(raw_text).get_text()
    
    # Remove non-letters.
    letters_only = re.sub("[^a-zA-Z]", " ", post_text)
    
    # Convert to lower case, split into individual words.
    words = letters_only.lower().split()
    
    # convert the stopwords to a set.
    stops = set(stop_words)
    
    # Remove stopwords.
    meaningful_words = [w for w in words if w not in stops]
    
    # Stemming 
    #p_stemmer = PorterStemmer()
    #meaningful_words = [p_stemmer.stem(w) for w in meaningful_words]
    
    #Lemmatize
    lemmatizer = WordNetLemmatizer()
    meaningful_words = [lemmatizer.lemmatize(word) for word in 
                        meaningful_words]
    
    
    
    
    # Join the words back into one string separated by space, 
    # and return the result.
    return(" ".join(meaningful_words))

# %%
new_reviews.columns
# Out:
# Index(['asin', 'name', 'rating', 'date', 'verified', 'review_title', 'body',
#        'helpfulVotes', 'brand', 'item_title', 'url', 'image', 'reviewUrl',
#        'totalReviews', 'price', 'originalPrice', 'sellers', 'reviews'],
#       dtype='object')

# %%
cleaned_reviews = []

print("Cleaning and parsing all reviews...")

# Instantiate counter.
j = 0

# For every review in our combined dataframe

for review in new_reviews['reviews']:
    
    # Apply the function that we created earlier to clean the reviews
    cleaned_reviews.append(clean_reviews(review))
    j += 1
    
print("Completed")
# Out:
# Cleaning and parsing all reviews...
# Completed

# %%
new_reviews['cleaned_reviews'] = cleaned_reviews

# %%
google_cleaned_reviews = []

print("Cleaning and parsing xiaomi reviews...")

# Instantiate counter.
j = 0

# For every review in our combined dataframe

for review in google_reviews['reviews']:
    
    # Apply the function that we created earlier to clean the reviews
    google_cleaned_reviews.append(clean_reviews(review))
    j += 1
    
print("Completed")

#Repeating the same steps for the other brands
apple_cleaned_reviews = []
print("Cleaning and parsing apple reviews...")
j = 0
for review in apple_reviews['reviews']:
    apple_cleaned_reviews.append(clean_reviews(review))
    j += 1
print("Completed")
# Out:
# Cleaning and parsing xiaomi reviews...
# Completed
# Cleaning and parsing apple reviews...
# Completed

# %%
def get_one_gram(corpus, n=None):
    """
    List the top n words in a vocabulary according to occurrence in a text corpus.
    """
    vec = CountVectorizer().fit(corpus)
    bag_of_words = vec.transform(corpus)
    sum_words = bag_of_words.sum(axis=0) 
    words_freq = [(word, sum_words[0, idx]) for word, idx in vec.vocabulary_.items()]
    words_freq =sorted(words_freq, key = lambda x: x[1], reverse=True)
    return words_freq[:n]


def get_phrase(corpus, n=None):
    """
    List the top n words in a vocabulary according to occurrence in a text corpus.
    """
    vec = CountVectorizer(ngram_range=(2, 4)).fit(corpus)
    bag_of_words = vec.transform(corpus)
    sum_words = bag_of_words.sum(axis=0) 
    words_freq = [(word, sum_words[0, idx]) for word, idx in vec.vocabulary_.items()]
    words_freq =sorted(words_freq, key = lambda x: x[1], reverse=True)
    return words_freq[:n]

# %%
top_google_words = dict(get_one_gram(google_cleaned_reviews,20))
top_google_phrase = dict(get_phrase(google_cleaned_reviews,20))

# %%
top_apple_words = dict(get_one_gram(apple_cleaned_reviews,20))
top_apple_phrase = dict(get_phrase(apple_cleaned_reviews,20))

# %%
#Create subplots
fig, axes = plt.subplots(1,2, figsize=(15,9));

#plot google reviews top 20 most frequently occuring words
plt.subplot(1,2,1)
covid_pos = plt.barh(range(len(top_google_words)), top_google_words.values(),align = 'center',color='xkcd:rust');

#Label axes 
plt.yticks(range(len(top_google_words)),top_google_words.keys(),fontsize=12);
plt.title('Top 20 words in Google Reviews')
plt.xlabel('Frequency')
plt.gca().invert_yaxis()


#plot apple reviews top 20 most frequently occuring words
plt.subplot(1,2,2)
covid_pos = plt.barh(range(len(top_apple_words)), top_apple_words.values(),align = 'center',color='xkcd:light orange');

#Label axes
plt.yticks(range(len(top_apple_words)),top_apple_words.keys(),fontsize=12);
plt.title('Top 20 words in Apple Reviews')
plt.xlabel('Frequency')
plt.gca().invert_yaxis()

plt.subplots_adjust(wspace=0.9)
plt.show()

# %%
#Create subplots
fig, axes = plt.subplots(1,2, figsize=(15,9));

#plot xiaomi reviews top 20 most frequently occuring words
plt.subplot(1,2,1)
covid_pos = plt.barh(range(len(top_google_phrase)), top_google_phrase.values(),align = 'center',color='xkcd:rust');

#Label axes 
plt.yticks(range(len(top_google_phrase)),top_google_phrase.keys(),fontsize=12);
plt.title('Top 20 phrases in Google Reviews')
plt.xlabel('Frequency')
plt.gca().invert_yaxis()


#plot apple reviews top 20 most frequently occuring words
plt.subplot(1,2,2)
covid_pos = plt.barh(range(len(top_apple_phrase)), top_apple_phrase.values(),align = 'center',color='xkcd:light orange');

#Label axes
plt.yticks(range(len(top_apple_phrase)),top_apple_phrase.keys(),fontsize=12);
plt.title('Top 20 phrases in Apple Reviews')
plt.xlabel('Frequency')
plt.gca().invert_yaxis()

plt.subplots_adjust(wspace=0.9)
plt.show()

# %% [markdown]
# From the most frequently occuring words, we can see that battery life, sim card seems to something that is very frequently discussed in reviews.

# %% [markdown]
# ## Modeling - Classification Technique

# %%
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import Pipeline

# %%
#map the ratings to positive vs negative ratings
new_reviews['rating'].unique()
# Out:
# array([3, 1, 5, 4, 2])

# %%
def positive_or_negative(rating):
    if rating >= 4:
        return 1
    else:
        return 0
    

new_reviews['pos_neg_reviews'] = new_reviews['rating'].map(positive_or_negative)

# %%
# Create the feature and target variable
X = new_reviews['cleaned_reviews']
y = new_reviews['pos_neg_reviews']

# %%
# Create train_test_split.
X_train, X_test, y_train, y_test = train_test_split(X,
                                                    y,
                                                    test_size = 0.25,
                                                    random_state = 42,
                                                    stratify= y)

# %%
X_train
# Out:
# 35934    everything great except yellow spot top left e...
# 17706                             star buy new new plastic
# 38743           star nice got great deal thanks amazon nov
# 48793                                             bad good
# 41018    great shape great shape several month still pr...
#                                ...
# 45306    star came mail fast clean scratch glass screen...
# 67848                                            good good
# 5504                                   star exactly wanted
# 10304    nokia first window purchased still many apps i...
# 9538                                 star excited got good
# Name: cleaned_reviews, Length: 50960, dtype: object

# %%
y_train.value_counts(normalize=True)
# Out:
# 1    0.685027
# 0    0.314973
# Name: pos_neg_reviews, dtype: float64

# %%
baseline_model = y_train.value_counts(normalize=True)
baseline_accuracy = round(baseline_model[0],3)

print(f"Baseline accuracy: {baseline_accuracy}")
# Out:
# Baseline accuracy: 0.315

# %%
#Instantiate the pipeline
lr_cvec_pipe = Pipeline([
    ('cvec', CountVectorizer()),
    ('lr',LogisticRegression(random_state=42,solver='liblinear', max_iter=10000))
])

#create hyperparameters for gridsearch
lr_cvec_params = {
    'cvec__max_features': [2000,3000,4000,5000],
    'cvec__min_df':[2,3],
    'cvec__max_df':[0.9,0.95],
    'cvec__ngram_range': [(1,1), (1,2)],
    'lr__C':[0.01,0.1,1,10],
    'lr__penalty': ['l1', 'l2']
}

# Instantiate GridSearchCV.
lr_cvec_gs = GridSearchCV(lr_cvec_pipe, # what object are we optimizing?
                  param_grid=lr_cvec_params , # what parameters values are we searching?
                  cv=5,
                 n_jobs=-1,verbose=1) 

#fit the model
lr_cvec_gs.fit(X_train,y_train)

# %%
training_accuracy_score = round(lr_cvec_gs.score(X_train,y_train),3)
testing_accuracy_score = round(lr_cvec_gs.score(X_test,y_test),3)

print(f"Logistic Regression CVEC Train Accuracy Score: {training_accuracy_score}")
print(f"Logistic Regression CVEC Test Accuracy Score: {testing_accuracy_score}")

# %%
lr_cvec_gs.best_params_

# %%
best_lr_cvec = Pipeline([
    ('cvec', CountVectorizer(max_df=0.9, max_features=5000, min_df= 3, ngram_range=(1, 2))),
    ('lr',LogisticRegression(random_state=42,solver='liblinear', max_iter=10000,C=0.1,penalty='l2'))
     ])


best_lr_cvec.fit(X_train,y_train)

# %%
training_accuracy_score = round(best_lr_cvec.score(X_train,y_train),3)
testing_accuracy_score = round(best_lr_cvec.score(X_test,y_test),3)

print(f"Logistic Regression CVEC Train Accuracy Score: {training_accuracy_score}")
print(f"Logistic Regression CVEC Test Accuracy Score: {testing_accuracy_score}")

# %% [markdown]
# # Inferential Findings and Analysis

# %%
reviews_vocab = best_lr_cvec.named_steps['lr'].coef_

# %%
neg_reviews = reviews_vocab * -1

# %%
features = best_lr_cvec.named_steps['cvec'].get_feature_names()

# %%
positive_reviews = dict(pd.Series(np.exp(reviews_vocab[0]), features).sort_values(ascending=False).head(20))
positive_reviews

# %%
negative_reviews = dict(pd.Series(np.exp(neg_reviews[0]), features).sort_values(ascending=False).head(20))
negative_reviews

# %%
cvec = CountVectorizer()

# %%
X_train_corpus = cvec.fit_transform(X_train)
X_test_corpus = cvec.transform(X_test)

# %%
from sklearn.decomposition import LatentDirichletAllocation

lda = LatentDirichletAllocation()
lda.fit(X_train_corpus)

# %%
lda.components_.shape

# %%
dict(pd.Series(np.exp(reviews_vocab[0]), features).sort_values(ascending=False).head(20))

# %%
len(cvec.get_feature_names())

# %%
def print_topn_words(model, feature_names, topn):
    for topic_idx, topic in enumerate(model.components_):
        message = "Topic #%d: " % topic_idx
        message += " ".join([feature_names[i]
                             for i in topic.argsort()[:-topn - 1:-1]])
        print(message)
    print()

# %%
print_topn_words(lda, cvec.get_feature_names(), 10)

# %% [markdown]
# ### With Gensim

# %%
# Gensim
import gensim, spacy, logging, warnings
from gensim.models.ldamodel import LdaModel
from gensim.models.ldamulticore import LdaMulticore
import gensim.corpora as corpora
from gensim.utils import lemmatize, simple_preprocess
from gensim.models import CoherenceModel
from gensim.models.phrases import Phrases, Phraser
from pprint import pprint

# %%
new_reviews['tokens'] = new_reviews['cleaned_reviews'].map(lambda x:x.split())

# %%
tokens = list(new_reviews['tokens'])

# %%
len(tokens)
# Out:
# 67947

# %%
tokens[0:2]
# Out:
# [['def',
#   'best',
#   'worst',
#   'samsung',
#   'awhile',
#   'absolute',
#   'doo',
#   'doo',
#   'read',
#   'review',
#   'detect',
#   'rage',
#   'stupid',
#   'thing',
#   'finally',
#   'died',
#   'used',
#   'nokia',
#   'bought',
#   'garage',
#   'sale',
#   'wonder',
#   'sold',
#   'cheap',
#   'bad',
#   'hate',
#   'menu',
#   'take',
#   'forever',
#   'get',
#   'want',
#   'scroll',
#   'endlessly',
#   'usually',
#   'phone',
#   'numbered',
#   'category',
#   'u',
#   'simply',
#   'press',
#   'get',
#   'want',
#   'go',
#   'pain',
#   'put',
#   'silent',
#   'vibrate',
#   'class',
#   'ring',
#   'turn',
#   'immediately',
#   'fast',
#   'way',
#   'silence',
#   'damn',
#   'thing',
#   'always',
#   'remember',
#   'put',
#   'silent',
#   'learned',
#   'hard',
#   'way',
#   'true',
#   'case',
#   'mission',
#   'get',
#   'break',
#   'ur',
#   'nail',
#   'process',
#   'also',
#   'damage',
#   'case',
#   'time',
#   'u',
#   'try',
#   'reason',
#   'started',
#   'giving',
#   'problem',
#   'succeed',
#   'opening',
#   'button',
#   'could',
#   'bit',
#   'bigger',
#   'vibration',
#   'could',
#   'stronger',
#   'good',
#   'reception',
#   'shabby',
#   'using',
#   'elevator',
#   'remarkable',
#   'feat',
#   'considering',
#   'old',
#   'would',
#   'lose',
#   'service',
#   'simply',
#   'putting',
#   'pocket',
#   'compared',
#   'old',
#   'samsung',
#   'work',
#   'quite',
#   'well',
#   'ring',
#   'tone',
#   'loud',
#   'enough',
#   'hear',
#   'actually',
#   'charge',
#   'quickly',
#   'great',
#   'battery',
#   'life',
#   'heat',
#   'like',
#   'potatoe',
#   'oven',
#   'either',
#   'long',
#   'convos',
#   'nice',
#   'bright',
#   'large',
#   'screen',
#   'cute',
#   'way',
#   'customize',
#   'scroll',
#   'bar',
#   'set',
#   'purple',
#   'pink',
#   'aqua',
#   'orange',
#   'etc',
#   'overall',
#   'okay',
#   'serf',
#   'purpose',
#   'definitely',
#   'pale',
#   'comparison',
#   'new',
#   'phone',
#   'coming',
#   'sprint',
#   'get',
#   'get',
#   'great'],
#  ['text',
#   'messaging',
#   'work',
#   'due',
#   'software',
#   'issue',
#   'nokia',
#   'sprint',
#   'text',
#   'messaging',
#   'capability',
#   'work',
#   'sprint',
#   'system',
#   'software',
#   'patch',
#   'come',
#   'time',
#   'next',
#   'month',
#   'spend',
#   'least',
#   'hour',
#   'sprint',
#   'award',
#   'winning',
#   'customer',
#   'service',
#   'team',
#   'find',
#   'someone',
#   'admit',
#   'problem',
#   'nokia',
#   'designed',
#   'phone',
#   'incoming',
#   'message',
#   'retrieved',
#   'quickly',
#   'viewed',
#   'offline',
#   'way',
#   'provider',
#   'work',
#   'sprint',
#   'however',
#   'like',
#   'people',
#   'hook',
#   'server',
#   'first',
#   'stay',
#   'connected',
#   'burning',
#   'minute',
#   'check',
#   'inbox',
#   'compose',
#   'reply',
#   'wait',
#   'sprint',
#   'server',
#   'respond',
#   'send',
#   'innovation',
#   'money',
#   'making',
#   'finest']]

# %%
#Build the bigram and trigram models
bigram = Phrases(tokens, min_count=5, threshold=100) # higher threshold fewer phrases.
trigram = Phrases(bigram[tokens], threshold=100)  
bigram_mod = Phraser(bigram)
trigram_mod = Phraser(trigram)

# %%
def process_words(texts, stop_words=stop_words, allowed_postags=['NOUN','VERB','ADV']):
    """Remove Stopwords, Form Bigrams, Trigrams and Lemmatization"""
    texts = [[word for word in simple_preprocess(str(doc)) if word not in stop_words] for doc in texts]
    texts = [bigram_mod[doc] for doc in texts]
    texts = [trigram_mod[bigram_mod[doc]] for doc in texts]
    texts_out = []
    nlp = spacy.load('en', disable=['parser', 'ner'])
    for sent in texts:
        doc = nlp(" ".join(sent)) 
        texts_out.append([token.lemma_ for token in doc if token.pos_ in allowed_postags])
    # remove stopwords once more after lemmatization
    texts_out = [[word for word in simple_preprocess(str(doc)) if word not in stop_words] for doc in texts_out]    
    return texts_out

data_ready = process_words(tokens)  # processed Text Data!

# %%
id2word = corpora.Dictionary(data_ready)
corpus = [id2word.doc2bow(line) for line in data_ready]

# %%
new_reviews.shape
# Out:
# (67947, 20)

# %%
len(corpus)
# Out:
# 67947

# %%
#Train the LDA model
# Build LDA model
lda_model = LdaMulticore(corpus=corpus,
                         id2word=id2word,
                         num_topics=10, 
                         random_state=100,
                        #update_every=1,
                         chunksize=100,
                         passes=10,
                         iterations=100,
                         per_word_topics=True)

pprint(lda_model.print_topics())
# Out:
# [(0,
#   '0.049*"camera" + 0.041*"use" + 0.029*"app" + 0.020*"picture" + 0.020*"take" '
#   '+ 0.019*"best" + 0.019*"feature" + 0.019*"ever" + 0.019*"android" + '
#   '0.016*"video"'),
#  (1,
#   '0.059*"screen" + 0.026*"camera" + 0.025*"quality" + 0.016*"price" + '
#   '0.015*"case" + 0.015*"use" + 0.014*"feel" + 0.014*"look" + 0.013*"display" '
#   '+ 0.012*"get"'),
#  (2,
#   '0.071*"come" + 0.043*"brand" + 0.038*"look" + 0.037*"condition" + '
#   '0.035*"scratch" + 0.035*"charger" + 0.028*"purchase" + 0.024*"box" + '
#   '0.023*"arrive" + 0.019*"receive"'),
#  (3,
#   '0.248*"work" + 0.030*"network" + 0.027*"great" + 0.025*"carrier" + '
#   '0.025*"unlock" + 0.024*"well" + 0.021*"use" + 0.021*"return" + '
#   '0.019*"perfectly" + 0.016*"mobile"'),
#  (4,
#   '0.180*"battery" + 0.084*"life" + 0.065*"charge" + 0.056*"day" + 0.030*"use" '
#   '+ 0.017*"hour" + 0.014*"fast" + 0.012*"really" + 0.011*"get" + '
#   '0.010*"camera"'),
#  (5,
#   '0.117*"far" + 0.078*"value" + 0.073*"money" + 0.050*"price" + 0.033*"buy" + '
#   '0.033*"protector" + 0.023*"complaint" + 0.019*"good" + 0.018*"spend" + '
#   '0.015*"reception"'),
#  (6,
#   '0.032*"buy" + 0.025*"month" + 0.024*"get" + 0.019*"time" + 0.018*"issue" + '
#   '0.018*"go" + 0.018*"call" + 0.017*"screen" + 0.016*"would" + '
#   '0.016*"problem"'),
#  (7,
#   '0.020*"use" + 0.018*"note" + 0.015*"go" + 0.015*"update" + 0.015*"get" + '
#   '0.012*"review" + 0.012*"set" + 0.011*"card" + 0.011*"issue" + '
#   '0.011*"device"'),
#  (8,
#   '0.095*"product" + 0.077*"buy" + 0.056*"card" + 0.041*"sim" + 0.036*"would" '
#   '+ 0.028*"seller" + 0.022*"service" + 0.022*"recommend" + 0.022*"price" + '
#   '0.017*"use"'),
#  (9,
#   '0.309*"love" + 0.153*"price" + 0.064*"really" + 0.033*"thank" + '
#   '0.031*"fast" + 0.020*"get" + 0.019*"better" + 0.018*"feature" + '
#   '0.017*"cell" + 0.015*"wife"')]

# %%
lda_model.per_word_topics
# Out:
# True

# %%
def format_topics_sentences(ldamodel=None, corpus=corpus, texts=None):
    # Init output
    sent_topics_df = pd.DataFrame()

    # Get main topic in each document
    for i, row_list in enumerate(ldamodel[corpus]):
        row = row_list[0] if ldamodel.per_word_topics else row_list            
        # print(row)
        row = sorted(row, key=lambda x: (x[1]), reverse=True)
        # Get the Dominant topic, Perc Contribution and Keywords for each document
        for j, (topic_num, prop_topic) in enumerate(row):
            if j == 0:  # => dominant topic
                wp = ldamodel.show_topic(topic_num)
                topic_keywords = ", ".join([word for word, prop in wp])
                sent_topics_df = sent_topics_df.append(pd.Series([int(topic_num), round(prop_topic,4), topic_keywords]), ignore_index=True)
            else:
                break
    sent_topics_df.columns = ['Dominant_Topic', 'Perc_Contribution', 'Topic_Keywords']

    # Add original text to the end of the output
    contents = pd.Series(texts)
    sent_topics_df = pd.concat([sent_topics_df, contents], axis=1)
    return(sent_topics_df)


df_topic_sents_keywords = format_topics_sentences(ldamodel=lda_model, corpus=corpus, texts=data_ready)

# Format
df_dominant_topic = df_topic_sents_keywords.reset_index()
df_dominant_topic.columns = ['Document_No', 'Dominant_Topic', 'Topic_Perc_Contrib', 'Keywords', 'Text']
df_dominant_topic.head(10)
# Out:
#    Document_No  Dominant_Topic  Topic_Perc_Contrib  \
# 0            0             1.0              0.4581
# 1            1             7.0              0.3230
# 2            2             0.0              0.6677
# 3            3             6.0              0.4859
# 4            4             1.0              0.3639
# 5            5             6.0              0.3807
# 6            6             1.0              0.3315
# 7            7             7.0              0.3619
# 8            8             1.0              0.4597
# 9            9             0.0              0.3319
#
#                                             Keywords  \
# 0  screen, get, make, camera, use, feel, look, go...
# 1  card, use, work, get, sim, call, say, carrier,...
# 2  app, use, update, device, android, set, softwa...
# 3  buy, get, month, time, issue, go, problem, wou...
# 4  screen, get, make, camera, use, feel, look, go...
# 5  buy, get, month, time, issue, go, problem, wou...
# 6  screen, get, make, camera, use, feel, look, go...
# 7  card, use, work, get, sim, call, say, carrier,...
# 8  screen, get, make, camera, use, feel, look, go...
# 9  app, use, update, device, android, set, softwa...
#
#                                                 Text
# 0  [best, samsung, awhile, review, detect, rage, ...
# 1  [text, messaging, work, software, issue, messa...
# 2  [love, also, purchase, die, menu, easily, spee...
# 3  [love, love, really, need, price, bill, receiv...
# 4  [option, case, purpose, offer, day, buy, could...
# 5  [work, use, decide, buy, flip, problem, batter...
# 6  [cool, color, word, describe, perfectly, mean,...
# 7  [headset, overall, make, headset, even, call, ...
# 8  [never, first, really, alot, reception, even, ...
# 9  [bit, school, need, text, messaging, month, te...

# %%
pd.options.display.max_colwidth = 150
df_dominant_topic[df_dominant_topic['Dominant_Topic'] == 9].sample(5)
# Out:
#        Document_No  Dominant_Topic  Topic_Perc_Contrib  \
# 57439        57439             9.0              0.1000
# 53375        53375             9.0              0.4200
# 64751        64751             9.0              0.5500
# 48755        48755             9.0              0.5250
# 33450        33450             9.0              0.6833
#
#                                                               Keywords  \
# 57439  love, price, buy, best, ever, really, feature, thank, fast, get
# 53375  love, price, buy, best, ever, really, feature, thank, fast, get
# 64751  love, price, buy, best, ever, really, feature, thank, fast, get
# 48755  love, price, buy, best, ever, really, feature, thank, fast, get
# 33450  love, price, buy, best, ever, really, feature, thank, fast, get
#
#                                    Text
# 57439                           [viejo]
# 53375   [come, work, especially, price]
# 64751                           [price]
# 48755               [money, best, ever]
# 33450  [love, arrive, love, love, love]

# %%
new_reviews.loc[26610,'reviews']
# Out:
# 'Bites the dust on Android update- Buyer Beware Phone crashes during Android 8.1 update and cannot be recovered. Google will not admit fault and you will be left with a very expensive paperweight. Buyer beware!!!'

# %%
# 1. Wordcloud of Top N words in each topic
from wordcloud import WordCloud, STOPWORDS
import matplotlib.colors as mcolors

cols = [color for name, color in mcolors.TABLEAU_COLORS.items()]  # more colors: 'mcolors.XKCD_COLORS'

cloud = WordCloud(stopwords=stop_words,
                  background_color='white',
                  width=2500,
                  height=1800,
                  max_words=10,
                  colormap='tab10',
                  color_func=lambda *args, **kwargs: cols[i],
                  prefer_horizontal=1.0)

topics = lda_model.show_topics(formatted=False)

fig, axes = plt.subplots(5, 2, figsize=(15,15), sharex=True, sharey=True)

for i, ax in enumerate(axes.flatten()):
    fig.add_subplot(ax)
    topic_words = dict(topics[i][1])
    cloud.generate_from_frequencies(topic_words, max_font_size=300)
    plt.gca().imshow(cloud)
    plt.gca().set_title('Topic ' + str(i), fontdict=dict(size=16))
    plt.gca().axis('off')


plt.subplots_adjust(wspace=0, hspace=0)
plt.axis('off')
plt.margins(x=0, y=0)
plt.tight_layout()
plt.show()

# %%
import pyLDAvis.gensim
pyLDAvis.enable_notebook()
vis = pyLDAvis.gensim.prepare(lda_model, corpus, dictionary=lda_model.id2word )
vis
# Out:
# PreparedData(topic_coordinates=              x         y  topics  cluster       Freq
# topic
# 1      0.135120  0.105555       1        1  18.824080
# 6      0.132858 -0.015113       2        1  17.928640
# 7      0.130206 -0.068293       3        1  15.215225
# 0      0.182172  0.063604       4        1  12.856235
# 4      0.115248  0.102989       5        1  12.192275
# 8     -0.084233 -0.120203       6        1   6.324888
# 2      0.095685 -0.140456       7        1   4.794336
# 5     -0.235492  0.147971       8        1   4.207265
# 3     -0.223191 -0.299742       9        1   4.103863
# 9     -0.248373  0.223687      10        1   3.553191, topic_info=        Term          Freq         Total Category  logprob  loglift
# 94      work  25326.000000  25326.000000  Default  30.0000  30.0000
# 144     love  12305.000000  12305.000000  Default  29.0000  29.0000
# 6    battery  13909.000000  13909.000000  Default  28.0000  28.0000
# 149    price  12125.000000  12125.000000  Default  27.0000  27.0000
# 69    screen  17538.000000  17538.000000  Default  26.0000  26.0000
# ..       ...           ...           ...      ...      ...      ...
# 521   iphone    258.291260   2130.296387  Topic10  -5.0989   1.2274
# 90      want    339.669403   5659.810547  Topic10  -4.8250   0.5242
# 2     always    195.470093   1971.456909  Topic10  -5.3776   1.0262
# 82     thing    216.384506   5342.875977  Topic10  -5.2760   0.1309
# 145     much    178.359833   3314.805908  Topic10  -5.4692   0.4150
#
# [658 rows x 6 columns], token_table=      Topic      Freq        Term
# term
# 3769      8  0.987124      abroad
# 391       1  0.365435  absolutely
# 391       2  0.112442  absolutely
# 391       4  0.101197  absolutely
# 391       6  0.308590  absolutely
# ...     ...       ...         ...
# 296       5  0.040929        year
# 296       8  0.032043        year
# 296      10  0.043891        year
# 2619      5  0.998589     youtube
# 2378      5  0.995164        zoom
#
# [1243 rows x 3 columns], R=30, lambda_step=0.01, plot_opts={'xlab': 'PC1', 'ylab': 'PC2'}, topic_order=[2, 7, 8, 1, 5, 9, 3, 6, 4, 10])

# %%
#mallet_path = './data/mallet-2.0.8/bin/mallet' # update this path
#ldamallet = gensim.models.wrappers.LdaMallet(mallet_path, corpus=corpus, num_topics=20, id2word=dct)

# %%
from gensim.models.coherencemodel import CoherenceModel

# %%
coherence_score = CoherenceModel(model=lda_model, texts=data_ready, dictionary=id2word, coherence='c_v')

# %%
coherence_score.get_coherence()
# Out:
# 0.48777572320389107

# %%
def compute_coherence_values(dictionary, corpus, texts, limit, start=2, step=3):
    """
    Compute c_v coherence for various number of topics

    Parameters:
    ----------
    dictionary : Gensim dictionary
    corpus : Gensim corpus
    texts : List of input texts
    limit : Max num of topics

    Returns:
    -------
    model_list : List of LDA topic models
    coherence_values : Coherence values corresponding to the LDA model with respective number of topics
    """
    coherence_values = []
    model_list = []
    for num_topics in range(start, limit, step):
        print(f"Model with {num_topics} topics")
        print(f"Fitting model {num_topics} out of {limit-1}")
        #model=LdaMulticore(corpus=corpus, id2word=dictionary, num_topics=num_topics,random_state=42)
        model=LdaModel(corpus=corpus,
                           id2word=dictionary,
                           num_topics=num_topics, 
                           random_state=100,
                           chunksize=100,
                           passes=10,
                           iterations=100,
                           per_word_topics=True)
        model_list.append(model)
        coherencemodel = CoherenceModel(model=model, texts=texts, dictionary=dictionary, coherence='u_mass',processes=1)
        print(f"Finding the coherence score of model {num_topics} ")
        coherence_values.append(coherencemodel.get_coherence())

    return model_list, coherence_values

# %%
model_list, coherence_values = compute_coherence_values(dictionary=id2word, corpus=corpus, texts=data_ready, start=5, limit=11, step=1)
# Out:
# Model with 5 topics
# Fitting model 5 out of 10
# Finding the coherence score of model 5
# Model with 6 topics
# Fitting model 6 out of 10
# Finding the coherence score of model 6
# Model with 7 topics
# Fitting model 7 out of 10
# Finding the coherence score of model 7
# Model with 8 topics
# Fitting model 8 out of 10
# Finding the coherence score of model 8
# Model with 9 topics
# Fitting model 9 out of 10
# Finding the coherence score of model 9
# Model with 10 topics
# Fitting model 10 out of 10
# Finding the coherence score of model 10

# %%
# Show graph
plt.figure(figsize=(10,6))
#limit=11; start=5; step=1;
x = range(5, 11)
plt.plot(x, coherence_values,label='u_mass coherence values')
plt.xlabel("Num Topics")
plt.ylabel("Coherence score")
plt.legend()
plt.show()

# %%
def compute_coherence_values(dictionary, corpus, texts, limit, start=2, step=3):
    """
    Compute c_v coherence for various number of topics

    Parameters:
    ----------
    dictionary : Gensim dictionary
    corpus : Gensim corpus
    texts : List of input texts
    limit : Max num of topics

    Returns:
    -------
    model_list : List of LDA topic models
    coherence_values : Coherence values corresponding to the LDA model with respective number of topics
    """
    coherence_values = []
    model_list = []
    for num_topics in range(start, limit, step):
        print(f"Model with {num_topics} topics")
        print(f"Fitting model {num_topics} out of {limit-1}")
        #model=LdaMulticore(corpus=corpus, id2word=dictionary, num_topics=num_topics,random_state=42)
        model=LdaModel(corpus=corpus,
                           id2word=dictionary,
                           num_topics=num_topics, 
                           random_state=100,
                           chunksize=100,
                           passes=10,
                           iterations=100,
                           per_word_topics=True)
        model_list.append(model)
        coherencemodel = CoherenceModel(model=model, texts=texts, dictionary=dictionary, coherence='c_v',processes=1)
        print(f"Finding the coherence score of model {num_topics} ")
        coherence_values.append(coherencemodel.get_coherence())

    return model_list, coherence_values

# %%
model_list, coherence_values = compute_coherence_values(dictionary=id2word, corpus=corpus, texts=data_ready, start=5, limit=11, step=1)
# Out:
# Model with 5 topics
# Fitting model 5 out of 10
# Finding the coherence score of model 5
# Model with 6 topics
# Fitting model 6 out of 10
# Finding the coherence score of model 6
# Model with 7 topics
# Fitting model 7 out of 10
# Finding the coherence score of model 7
# Model with 8 topics
# Fitting model 8 out of 10
# Finding the coherence score of model 8
# Model with 9 topics
# Fitting model 9 out of 10
# Finding the coherence score of model 9
# Model with 10 topics
# Fitting model 10 out of 10
# Finding the coherence score of model 10

# %%
# Show graph
plt.figure(figsize=(10,6))
#limit=11; start=5; step=1;
x = range(5, 11)
plt.plot(x, coherence_values,label='c_v coherence values')
plt.xlabel("Num Topics")
plt.ylabel("Coherence score")
plt.legend()
plt.show()

# %%
coherence_values
# Out:
# [0.5083829459305249,
#  0.5023922022571315,
#  0.44492935829144376,
#  0.44900465630284525,
#  0.4484643035517877,
#  0.43928998146302234]

# %%
optimal_model = model_list[0]

# %%
pprint(optimal_model.print_topics())
# Out:
# [(0,
#   '0.111*"price" + 0.085*"love" + 0.052*"work" + 0.041*"buy" + 0.028*"value" + '
#   '0.028*"product" + 0.026*"expect" + 0.025*"really" + 0.025*"far" + '
#   '0.024*"quality"'),
#  (1,
#   '0.033*"use" + 0.032*"camera" + 0.031*"battery" + 0.018*"get" + 0.015*"life" '
#   '+ 0.014*"take" + 0.014*"really" + 0.012*"make" + 0.012*"day" + 0.012*"app"'),
#  (2,
#   '0.105*"screen" + 0.028*"case" + 0.025*"display" + 0.019*"hand" + '
#   '0.018*"android" + 0.015*"back" + 0.014*"size" + 0.014*"feel" + '
#   '0.013*"button" + 0.013*"color"'),
#  (3,
#   '0.040*"work" + 0.029*"card" + 0.024*"device" + 0.020*"use" + 0.015*"say" + '
#   '0.014*"sim" + 0.012*"set" + 0.012*"carrier" + 0.012*"network" + '
#   '0.012*"come"'),
#  (4,
#   '0.051*"buy" + 0.044*"work" + 0.024*"get" + 0.024*"return" + 0.023*"issue" + '
#   '0.023*"month" + 0.022*"time" + 0.022*"problem" + 0.019*"charger" + '
#   '0.019*"would"')]

# %%
# 1. Wordcloud of Top N words in each topic
from wordcloud import WordCloud, STOPWORDS
import matplotlib.colors as mcolors

cols = [color for name, color in mcolors.TABLEAU_COLORS.items()]  # more colors: 'mcolors.XKCD_COLORS'

cloud = WordCloud(stopwords=stop_words,
                  background_color='white',
                  width=2500,
                  height=1800,
                  max_words=10,
                  colormap='tab10',
                  color_func=lambda *args, **kwargs: cols[i],
                  prefer_horizontal=1.0)

topics = optimal_model.show_topics(formatted=False)

fig, axes = plt.subplots(1, 5, figsize=(15,15), sharex=True, sharey=True)

for i, ax in enumerate(axes.flatten()):
    fig.add_subplot(ax)
    topic_words = dict(topics[i][1])
    cloud.generate_from_frequencies(topic_words, max_font_size=300)
    plt.gca().imshow(cloud)
    plt.gca().set_title('Topic ' + str(i), fontdict=dict(size=16))
    plt.gca().axis('off')


plt.subplots_adjust(wspace=0, hspace=0)
plt.axis('off')
plt.margins(x=0, y=0)
plt.tight_layout()
plt.show()

# %%
def compute_coherence_values(dictionary, corpus, texts, limit, start=2, step=3):
    """
    Compute c_v coherence for various number of topics

    Parameters:
    ----------
    dictionary : Gensim dictionary
    corpus : Gensim corpus
    texts : List of input texts
    limit : Max num of topics

    Returns:
    -------
    model_list : List of LDA topic models
    coherence_values : Coherence values corresponding to the LDA model with respective number of topics
    """
    coherence_values = []
    model_list = []
    for num_topics in range(start, limit, step):
        print(f"Model with {num_topics} topics")
        print(f"Fitting model {num_topics} out of {limit-1}...")
        #model=LdaMulticore(corpus=corpus, id2word=dictionary, num_topics=num_topics,random_state=42)
        model=LdaModel(corpus=corpus,
                           id2word=dictionary,
                           num_topics=num_topics, 
                           random_state=42,
                           chunksize=100,
                           passes=10,
                           iterations=100,
                           per_word_topics=True)
        model_list.append(model)
        coherencemodel = CoherenceModel(model=model, texts=texts, dictionary=dictionary, coherence='c_v',processes=1)
        print(f"Finding the coherence score of model {num_topics} ...")
        coherence_values.append(coherencemodel.get_coherence())

    return model_list, coherence_values

# %%
model_list, coherence_values = compute_coherence_values(dictionary=id2word, corpus=corpus, texts=data_ready, start=4, limit=11, step=1)
# Out:
# Model with 4 topics
# Fitting model 4 out of 10...
# Finding the coherence score of model 4 ...
# Model with 5 topics
# Fitting model 5 out of 10...
# Finding the coherence score of model 5 ...
# Model with 6 topics
# Fitting model 6 out of 10...
# Finding the coherence score of model 6 ...
# Model with 7 topics
# Fitting model 7 out of 10...
# Finding the coherence score of model 7 ...
# Model with 8 topics
# Fitting model 8 out of 10...
# Finding the coherence score of model 8 ...
# Model with 9 topics
# Fitting model 9 out of 10...
# Finding the coherence score of model 9 ...
# Model with 10 topics
# Fitting model 10 out of 10...
# Finding the coherence score of model 10 ...

# %%
# Show graph
plt.figure(figsize=(10,6))
#limit=11; start=5; step=1;
x = range(4, 11)
plt.plot(x, coherence_values,label='c_v coherence values')
plt.xlabel("Num Topics")
plt.ylabel("Coherence score")
plt.legend()
plt.show()
