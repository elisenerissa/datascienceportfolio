# %%
import pandas as pd

# %%
df = pd.read_csv('../data/reviews_with_feature_sentiments')

# %%
df.head(2)
# Out:
#          asin    name  rating               date  verified  \
# 0  B0000SX2UC   Janet       3   October 11, 2005     False
# 1  B0000SX2UC  Brooke       5  December 30, 2003     False
#
#                   review_title  \
# 0  Def not best, but not worst
# 1              Love This Phone
#
#                                                 body  helpfulVotes brand  \
# 0  I had the Samsung A600 for awhile which is abs...           1.0   NaN
# 1  This is a great, reliable phone. I also purcha...           5.0   NaN
#
#                                           item_title  ...  \
# 0  Dual-Band / Tri-Mode Sprint PCS Phone w/ Voice...  ...
# 1  Dual-Band / Tri-Mode Sprint PCS Phone w/ Voice...  ...
#
#                                      cleaned_reviews multi_class_sentiment  \
# 0  def best worst samsung awhile absolute doo doo...                     1
# 1  love great reliable also purchased samsung die...                     2
#
# ...
